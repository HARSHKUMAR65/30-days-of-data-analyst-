# %%
import pandas as pd 
import numpy as np 
import seaborn as  sns 
import matplotlib.pyplot as plt

# %%
customer_data=pd.read_csv("DIM_Customer.csv")
date_data=pd.read_csv("Dim_Date_Excel.csv")
product_data=pd.read_csv("DIM_Products.csv")
sale_data=pd.read_csv("FactInternetSale.csv")

# %%
customer_data
# Out:
#        CustomerKey First Name Last Name          Full Name  Gender  \
# 0            11000        Jon      Yang           Jon Yang    Male
# 1            11001     Eugene     Huang       Eugene Huang    Male
# 2            11002      Ruben    Torres       Ruben Torres    Male
# 3            11003    Christy       Zhu        Christy Zhu  Female
# 4            11004  Elizabeth   Johnson  Elizabeth Johnson  Female
# ...            ...        ...       ...                ...     ...
# 18479        29479      Tommy      Tang         Tommy Tang    Male
# 18480        29480       Nina      Raji          Nina Raji  Female
# 18481        29481       Ivan      Suri          Ivan Suri    Male
# 18482        29482    Clayton     Zhang      Clayton Zhang    Male
# 18483        29483      Jésus   Navarro      Jésus Navarro    Male
#
#       DateFirstPurchase     Customer City
# 0             1/19/2018       Rockhampton
# 1             1/15/2018           Seaford
# ...

# %%
date_data
# Out:
#        DateKey        Date        Day  WeekNumber     Month MonthShort  \
# 0     20190101    1/1/2019    Tuesday           1   January        Jan
# 1     20190102    1/2/2019  Wednesday           1   January        Jan
# 2     20190103    1/3/2019   Thursday           1   January        Jan
# 3     20190104    1/4/2019     Friday           1   January        Jan
# 4     20190105    1/5/2019   Saturday           1   January        Jan
# ...        ...         ...        ...         ...       ...        ...
# 1091  20211227  12/27/2021     Monday          53  December        Dec
# 1092  20211228  12/28/2021    Tuesday          53  December        Dec
# 1093  20211229  12/29/2021  Wednesday          53  December        Dec
# 1094  20211230  12/30/2021   Thursday          53  December        Dec
# 1095  20211231  12/31/2021     Friday          53  December        Dec
#
#       MonthNumber  Quater  Year
# 0               1       1  2019
# 1               1       1  2019
# ...

# %%
product_data
# Out:
#      ProductKey ProductItemCode           Product Name     Sub Category  \
# 0             1         AR-5381        Adjustable Race              NaN
# 1             2         BA-8327           Bearing Ball              NaN
# 2             3         BE-2349        BB Ball Bearing              NaN
# 3             4         BE-2908  Headset Ball Bearings              NaN
# 4             5         BL-2036                  Blade              NaN
# ..          ...             ...                    ...              ...
# 601         602         BB-8107      ML Bottom Bracket  Bottom Brackets
# 602         603         BB-9108      HL Bottom Bracket  Bottom Brackets
# 603         604      BK-R19B-44     Road-750 Black, 44       Road Bikes
# 604         605      BK-R19B-48     Road-750 Black, 48       Road Bikes
# 605         606      BK-R19B-52     Road-750 Black, 52       Road Bikes
#
#     Product Category Product Color Product Size Product Line  \
# ...
